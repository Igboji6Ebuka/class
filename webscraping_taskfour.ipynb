# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt
import re
pytesseract.pytesseract.tesseract_cmd = r"C:\Users\igboj\Downloads\tesseract-ocr-w64-setup-5.4.0.20240606.exe"

# %%
image_path = r"C:/Users/igboj/Desktop/sample/black towel/image_8.jpeg"
img = cv2.imread(image_path)

if img is None:
    raise FileNotFoundError(f"Image not found at the path: {image_path}")

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis('off') 
plt.show()

# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt

image_path = r"C:/Users/igboj/Desktop/sample/black towel/image_8.jpeg"
img = cv2.imread(image_path)

if img is None:
    raise FileNotFoundError(f"Image not found at the path: {image_path}")
img = cv2.resize(img, (600, 360))


extracted_text = pytesseract.image_to_string(img)

print("Extracted Text:\n", extracted_text)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis('off') 
plt.title('Result')
plt.show()
# Out:
# Extracted Text:

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
import os

data_dir = "C:/Users/igboj/Desktop/sample"

print("Contents of base directory:")
print(os.listdir(data_dir))

print("\nContents of train directory:")
print(os.listdir(f'{data_dir}/train'))

print("\nContents of validation directory:")
print(os.listdir(f'{data_dir}/validation'))
# Out:
# Contents of base directory:
# ['train', 'validation']
#
# Contents of train directory:
# ['BLACK TEA TOWEL CLASSIC DESIGN', 'WHITE METAL LANTERN']
#
# Contents of validation directory:
# ['BLACK TEA TOWEL CLASSIC DESIGN', 'WHITE METAL LANTERN']

# %%
import pandas as pd 
dict_ = {
    "name":["Ebuka","john","miracle"],
    "age":[40,22,34],
    "address":["newmarket","nkpor","obosi"]
}
print(dict_)
data_frame = pd.DataFrame(dict_)
print(data_frame)
# Out:
# {'name': ['Ebuka', 'john', 'miracle'], 'age': [40, 22, 34], 'address': ['newmarket', 'nkpor', 'obosi']}
#       name  age    address
# 0    Ebuka   40  newmarket
# 1     john   22      nkpor
# 2  miracle   34      obosi

# %%
import os

train_dir = os.path.join(data_dir, 'train')
validation_dir = os.path.join(data_dir, 'validation')


train_metal_dir = os.path.join(train_dir, 'WHITE METAL LANTERN')
train_towel_dir = os.path.join(train_dir, 'BLACK TEA TOWEL CLASSIC DESIGN')


validation_towel_dir = os.path.join(validation_dir, 'BLACK TEA TOWEL CLASSIC DESIGN')
validation_metal_dir = os.path.join(validation_dir, 'WHITE METAL LANTERN')

# %%
train_cat_fnames = os.listdir( train_metal_dir )
train_dog_fnames = os.listdir( train_towel_dir )

print(train_cat_fnames[:10])
print(train_dog_fnames[:10])
# Out:
# ['image_1.png', 'image_10.png', 'image_13.png', 'image_14.png', 'image_15.png', 'image_16.jpeg', 'image_16.png', 'image_17.png', 'image_18.jpeg', 'image_18.png']
# ['image_0.jpeg', 'image_1.jpeg', 'image_10.jpeg', 'image_10.png', 'image_100.jpeg', 'image_101.jpeg', 'image_102.jpeg', 'image_103.jpeg', 'image_104.jpeg', 'image_105.jpeg']

# %%
def analsyt_grade(ebuka,treasure,otito):
    return {"grade_one":ebuka,"grade_two":treasure,"grade_three":otito}
    #print(otito,ebuka,treasure)
analsyt_grade(10,20,39)
# Out:
# {'grade_one': 10, 'grade_two': 20, 'grade_three': 39}
